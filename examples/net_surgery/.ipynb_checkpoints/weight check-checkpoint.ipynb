# %%
import os
import numpy as np
caffe_root = '/home/flathead/bitbucket/mycaffe/'
os.chdir('../../')
import sys
sys.path.insert(0, 'python')
import caffe

# %%
from pylab import *
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from numpy.random import normal

# %%
caffe.set_mode_gpu()
caffe.set_device(0)

# %%
net1 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_10000.caffemodel.h5', caffe.TEST)
#net2 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_20000.caffemodel.h5', caffe.TEST)
#net3 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_30000.caffemodel.h5', caffe.TEST)
#net4 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_40000.caffemodel.h5', caffe.TEST)
#net5 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_50000.caffemodel.h5', caffe.TEST)
#net6 = caffe.Net('examples/cifar10/cifar10_full_train_test.prototxt','examples/cifar10/cifar10_full_iter_60000.caffemodel.h5', caffe.TEST)

# %%
#net1.params['conv1'][0].data[0]

# %%
plt.figure(figsize=(15, 15))

feat1 = net1.params['conv1'][0].data
feat2 = net1.params['conv2'][0].data
feat3 = net1.params['conv3'][0].data
feat4 = net1.params['ip1'][0].data

plt.subplot(2, 2, 1)
#plt.hist(train_net.params['ip1'][0].data)
plt.hist(feat1.flat, bins = 100)
#plt.title("ip1_weight")

#plt.xlabel("weight")
plt.subplot(2, 2, 2)
#plt.hist(train_net.params['ip2'][0].data)
plt.hist(feat2.flat, bins = 100)
#plt.title("ip2_weight")

plt.subplot(2, 2, 3)
#plt.hist(train_net.params['ip3'][0].data)
plt.hist(feat3.flat, bins = 100)
#plt.title("ip3_weight")

plt.subplot(2, 2, 4)
#plt.hist(train_net.params['ip4'][0].data)
plt.hist(feat4.flat, bins = 100)
#plt.title("ip4_weight")

#plt.subplot_tool()
plt.show()

# %%
std_ip1 = feat1.std()
print std_ip1
std_ip2 = feat2.std()
print std_ip2
std_ip3 = feat3.std()
print std_ip3
std_ip4 = feat4.std()
print std_ip4
# Out:
# 9.7959e-05
# 0.0100118
# 0.00998733
# 0.0125219
